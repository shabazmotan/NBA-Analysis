# %%
import pandas as pd

# %%
Reg22_df=pd.read_csv('RegSeason22.csv', encoding= 'latin1', delimiter=';')
Reg22_df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
Playoff22_df=pd.read_csv('RegSeason22.csv', encoding= 'latin1', delimiter=';')
Playoff22_df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
Reg22_df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
# TS%= PTS/(2*TSA)
# TSA=FGA+(.44*FTA)
# For loop through each player, build TSA --> TS%. Put into a column

Reg22_df['TSA']=(Reg22_df['FGA']+(.44*Reg22_df['FTA']))
Reg22_df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...  2.0
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...  4.6
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...  2.4
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...  1.0
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...  1.6
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...  1.5
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...  0.7
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...  1.5
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...  1.9
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...  2.9
#
# ...

# %%
Reg22_df['TS%']=(Reg22_df['PTS']/(2*Reg22_df['TSA']))

# %%
Playoff22_df['TSA']=(Playoff22_df['FGA']+(.44*Playoff22_df['FTA']))
Playoff22_df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...  2.0
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...  4.6
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...  2.4
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...  1.0
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...  1.6
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...  1.5
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...  0.7
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...  1.5
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...  1.9
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...  2.9
#
# ...

# %%
Playoff22_df['TS%']=(Playoff22_df['PTS']/(2*Playoff22_df['TSA']))

# %%
Reg22_df=Reg22_df.rename(columns= {
    'Rk': 'RK',
    'Tm': 'Team',
    'G': 'GamesPlayed',
    'GS': 'GamesStarted',
    'MP': 'MinutesPlayed',
    'FG%': 'FGPer',
    '3P': 'ThreePM',
    '3PA': 'ThreePA',
    '3P%': 'ThreePer',
    '2P':  'TwoPM',
    '2PA': 'TwoPA',
    '2P%': 'TwoPer',
    'eFG%': 'eFG_Per',
    'FT%': 'FT_Per',
    'TS%': 'TS_Per'
    })
Reg22_df
# Out:
#       RK             Player Pos  Age Team  GamesPlayed  GamesStarted  \
# 0      1   Precious Achiuwa   C   22  TOR           73            28
# 1      2       Steven Adams   C   28  MEM           76            75
# 2      3        Bam Adebayo   C   24  MIA           56            56
# 3      4       Santi Aldama  PF   21  MEM           32             0
# 4      5  LaMarcus Aldridge   C   36  BRK           47            12
# ..   ...                ...  ..  ...  ...          ...           ...
# 807  601     Thaddeus Young  PF   33  TOR           26             0
# 808  602         Trae Young  PG   23  ATL           76            76
# 809  603     Omer Yurtseven   C   23  MIA           56            12
# 810  604        Cody Zeller   C   29  POR           27             0
# 811  605        Ivica Zubac   C   24  LAC           76            76
#
#      MinutesPlayed   FG   FGA  ...  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  \
# ...

# %%
list(Playoff22_df.columns)
# Out:
# ['RK',
#  'Player',
#  'Pos',
#  'Age',
#  'Team',
#  'GamesPlayed',
#  'GamesStarted',
#  'MinutesPlayed',
#  'FG',
#  'FGA',
#  'FGPer',
#  'ThreePM',
#  'ThreePA',
#  'ThreePer',
#  'TwoPM',
#  'TwoPA',
#  'TwoPer',
#  'eFG_Per',
#  'FT',
#  'FTA',
#  'FT_Per',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'TSA',
#  'TS_Per']

# %%
Playoff22_df=Playoff22_df.rename(columns= {
    'Rk': 'RK',
    'Tm': 'Team',
    'G': 'GamesPlayed',
    'GS': 'GamesStarted',
    'MP': 'MinutesPlayed',
    'FG%': 'FGPer',
    '3P': 'ThreePM',
    '3PA': 'ThreePA',
    '3P%': 'ThreePer',
    '2P':  'TwoPM',
    '2PA': 'TwoPA',
    '2P%': 'TwoPer',
    'eFG%': 'eFG_Per',
    'FT%': 'FT_Per',
    'TS%': 'TS_Per'
    })
Playoff22_df
# Out:
#       RK             Player Pos  Age Team  GamesPlayed  GamesStarted  \
# 0      1   Precious Achiuwa   C   22  TOR           73            28
# 1      2       Steven Adams   C   28  MEM           76            75
# 2      3        Bam Adebayo   C   24  MIA           56            56
# 3      4       Santi Aldama  PF   21  MEM           32             0
# 4      5  LaMarcus Aldridge   C   36  BRK           47            12
# ..   ...                ...  ..  ...  ...          ...           ...
# 807  601     Thaddeus Young  PF   33  TOR           26             0
# 808  602         Trae Young  PG   23  ATL           76            76
# 809  603     Omer Yurtseven   C   23  MIA           56            12
# 810  604        Cody Zeller   C   29  POR           27             0
# 811  605        Ivica Zubac   C   24  LAC           76            76
#
#      MinutesPlayed   FG   FGA  ...  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  \
# ...

# %%
Reg22_df.to_csv('UpdatedReg22.csv', index=False)

# %%
Playoff22_df.to_csv('UpdatedPlayoff22.csv', index=False)

# %%
Reg22_json=Reg22_df.to_json
print(Reg22_json)
## Can't convert to JSON here
## Next Steps: Import into tables in database of choice
## Query tables using sqlalchemy
## Then from those queries, use flask to jsonify data
## Save jsonified data into arrays for calling in JS
# Out:
# <bound method NDFrame.to_json of       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  DRB  \
# 0      1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  ...  4.5
# 1      2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  ...  5.4
# 2      3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  ...  7.6
# 3      4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  ...  1.7
# 4      5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  ...  3.9
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 807  601     Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  ...  2.9
# 808  602         Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  ...  3.1
# 809  603     Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  ...  3.7
# 810  604        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...  2.8
# 811  605        Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  ...  5.6
#
# ...
